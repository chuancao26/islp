# %% [markdown]
# <a href="https://colab.research.google.com/github/chuancao26/islp/blob/main/unsaanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/machine_learning/Aplicaciones/unsa_analisis/dataset_2023-2025_v2 (1).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175442 entries, 0 to 175441
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ID                             175442 non-null  object
#  1   ANO_POSTULACION                175442 non-null  int64
#  2   MODALIDAD_POSTULACION          175442 non-null  object
#  3   FASE_POSTULACION               175442 non-null  int64
#  4   SEDE                           175442 non-null  object
#  5   SEXO                           175442 non-null  object
#  6   PAIS_NACIMIENTO                175442 non-null  object
#  7   DEPARTAMENTO_NACIMIENTO        175442 non-null  object
#  8   PROVINCIA_DEPARTAMENTO         175442 non-null  object
#  9   DISTRITO_NACIMIENTO            175442 non-null  object
#  10  TIPO_COLEGIO                   175442 non-null  object
#  11  PAIS_COLEGIO                   175442 non-null  object
# ...

# %% [markdown]
# # EDA

# %%
df.ANO_POSTULACION
# Out:
# 0         2023
# 1         2023
# 2         2023
# 3         2023
# 4         2023
#           ...
# 175437    2025
# 175438    2025
# 175439    2025
# 175440    2025
# 175441    2025
# Name: ANO_POSTULACION, Length: 175442, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'ANO_POSTULACION', 'MODALIDAD_POSTULACION', 'FASE_POSTULACION',
#        'SEDE', 'SEXO', 'PAIS_NACIMIENTO', 'DEPARTAMENTO_NACIMIENTO',
#        'PROVINCIA_DEPARTAMENTO', 'DISTRITO_NACIMIENTO', 'TIPO_COLEGIO',
#        'PAIS_COLEGIO', 'DEPARTAMENTO_COLEGIO', 'PROVINCIA_COLEGIO',
#        'DISTRITO_COLEGIO', 'DISCAPACIDAD', 'CONDICION',
#        'PROGRAMA_ESTUDIOS_POSTULACION', 'PROGRAMA_ESTUDIOS_INGRESO',
#        'PUNTAJE_FINAL'],
#       dtype='object')

# %%
df.MODALIDAD_POSTULACION.value_counts()
# Out:
# MODALIDAD_POSTULACION
# Ordinario                                                               96880
# Ceprunsa                                                                51576
# Ciclo Quintos                                                           22444
# Extraordinario-Primeros Puestos                                          2577
# Extraordinario-Titulados y Graduados                                      546
# Extraordinario-COAR                                                       499
# Extraordinario-Traslados Internos                                         372
# Extraordinario-Personas con Discapacidad                                  226
# Extraordinario-Traslados Externos                                         127
# Extraordinario-Deportistas Calificados                                     59
# Extraordinario-Victimas de Terrorismo                                      49
# Extraordinario-Victimas de Violencia                                       45
# ...
