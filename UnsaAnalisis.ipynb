# %% [markdown]
# <a href="https://colab.research.google.com/github/chuancao26/islp/blob/main/UnsaAnalisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/machine_learning/datasetUNSA.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175442 entries, 0 to 175441
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ID                             175442 non-null  object
#  1   ANO_POSTULACION                175442 non-null  int64
#  2   MODALIDAD_POSTULACION          175442 non-null  object
#  3   FASE_POSTULACION               175442 non-null  int64
#  4   SEDE                           175442 non-null  object
#  5   SEXO                           175442 non-null  object
#  6   PAIS_NACIMIENTO                175442 non-null  object
#  7   DEPARTAMENTO_NACIMIENTO        175442 non-null  object
#  8   PROVINCIA_DEPARTAMENTO         175442 non-null  object
#  9   DISTRITO_NACIMIENTO            175442 non-null  object
#  10  TIPO_COLEGIO                   175442 non-null  object
#  11  PAIS_COLEGIO                   175442 non-null  object
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175442 entries, 0 to 175441
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   id                             175442 non-null  object
#  1   ano_postulacion                175442 non-null  int64
#  2   modalidad_postulacion          175442 non-null  object
#  3   fase_postulacion               175442 non-null  int64
#  4   sede                           175442 non-null  object
#  5   sexo                           175442 non-null  object
#  6   pais_nacimiento                175442 non-null  object
#  7   departamento_nacimiento        175442 non-null  object
#  8   provincia_departamento         175442 non-null  object
#  9   distrito_nacimiento            175442 non-null  object
#  10  tipo_colegio                   175442 non-null  object
#  11  pais_colegio                   175442 non-null  object
# ...

# %%
df.sexo.value_counts()
# Out:
# sexo
# FEMENINO     90196
# MASCULINO    85246
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                   id  ano_postulacion  \
# 0  0fa4e1d2123ace72a0c07a556e927101d3b1fa3f96a9b0...             2023
# 1  ddd180a4466685b23ed9fee26d0d9cb5f081608808ccea...             2023
# 2  86d9f191c026ce1e0177d91e0428d28bb8f9365a8317b5...             2023
# 3  40da348e30958700742a602db7ed9e76da738625955924...             2023
# 4  634bce1b71598aee213035a6cc63d3f879d11a8cb7ce4f...             2023
#
#   modalidad_postulacion  fase_postulacion      sede       sexo  \
# 0             Ordinario                 1  AREQUIPA   FEMENINO
# 1             Ordinario                 1  AREQUIPA  MASCULINO
# 2             Ordinario                 1  AREQUIPA  MASCULINO
# 3             Ordinario                 1  AREQUIPA   FEMENINO
# 4             Ordinario                 1  AREQUIPA   FEMENINO
#
#   pais_nacimiento departamento_nacimiento provincia_departamento  \
# 0            PERÚ                AREQUIPA                 CAMANA
# ...

# %%
df[df.programa_estudios_postulacion == "MEDICINA"].groupby(by="departamento_nacimiento")["puntaje_final"].mean().sort_values(ascending=False)
# Out:
# departamento_nacimiento
# HUANCAVELICA             65.293677
# PIURA                    56.747469
# AREQUIPA                 51.322422
# LIMA                     50.036518
# TACNA                    49.467274
# JUNIN                    49.068567
# PUNO                     47.443816
# CUSCO                    47.336860
# APURIMAC                 47.077247
# LAMBAYEQUE               46.970583
# MOQUEGUA                 46.705132
# ICA                      46.704030
# CALLAO (PROV. CONST.)    46.116310
# TUMBES                   45.186832
# NO CORRESPONDE           45.055236
# CAJAMARCA                42.637604
# PERU                     42.491049
# PASCO                    42.000849
# MADRE DE DIOS            41.979133
# LORETO                   41.651340
# LA LIBERTAD              41.127890
# UCAYALI                  40.422520
# AYACUCHO                 40.307397
# AMAZONAS                 40.302262
# SAN MARTIN               33.375689
# HUANUCO                  31.706814
# ...
